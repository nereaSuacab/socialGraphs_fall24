# %%
from imdb import IMDb
import os

# %% [markdown]
# Check all the info that can be obtained using IMBdPY library with a example.

# %%
# Create an instance of the IMDb class
ia = IMDb()

# Search for the movie
movie_name = "The Shawshank Redemption"
movies = ia.search_movie(movie_name)

# Get the movie ID and fetch the movie details
movie_id = movies[0].movieID
movie = ia.get_movie(movie_id)

# show all information that are currently available for a movie
print(sorted(movie.keys()))

# show all information sets that can be fetched for a movie
print(ia.get_movie_infoset())
# Out:
# ['akas', 'art department', 'art direction', 'aspect ratio', 'assistant director', 'box office', 'camera and electrical department', 'canonical title', 'cast', 'casting department', 'casting director', 'certificates', 'cinematographer', 'color info', 'composer', 'costume department', 'costume designer', 'countries', 'country codes', 'cover url', 'director', 'distributors', 'editor', 'editorial department', 'full-size cover url', 'genres', 'imdbID', 'kind', 'language codes', 'languages', 'localized title', 'location management', 'long imdb canonical title', 'long imdb title', 'make up', 'miscellaneous crew', 'music department', 'original air date', 'original title', 'other companies', 'plot', 'plot outline', 'producer', 'production companies', 'production design', 'production manager', 'rating', 'runtimes', 'script department', 'set decoration', 'smart canonical title', 'smart long imdb canonical title', 'sound crew', 'sound mix', 'special effects', 'special effects companies', 'stunt performer', 'synopsis', 'thanks', 'title', 'top 250 rank', 'transportation department', 'videos', 'visual effects', 'votes', 'writer', 'year']
# ['airing', 'akas', 'alternate versions', 'awards', 'connections', 'crazy credits', 'critic reviews', 'episodes', 'external reviews', 'external sites', 'faqs', 'full credits', 'goofs', 'keywords', 'list', 'locations', 'main', 'misc sites', 'news', 'official sites', 'parents guide', 'photo sites', 'plot', 'quotes', 'recommendations', 'release dates', 'release info', 'reviews', 'sound clips', 'soundtrack', 'synopsis', 'taglines', 'technical', 'trivia', 'tv schedule', 'video clips', 'vote details']

# %% [markdown]
# Save all the relevant info into a txt file for all the movies in the top/bottom 250 movies and their related ones.

# %%
# Create an instance of the IMDb class
ia = IMDb()

# Read movie names directly from the text file
with open('bottom_net_movies_titles.txt', 'r', encoding='utf-8') as file:  #top_net_movies_titles.txt
    movie_names = [line.strip() for line in file.readlines()] #[146:]

# Create a folder to store the text files
output_folder = 'bottom_net_movies_info' #top_net_movies_info
os.makedirs(output_folder, exist_ok=True)

# Process each movie name
for index, movie_name in enumerate(movie_names, start=1):  # Use enumerate to get the index
    print(f"Creating text file for movie {index}/{len(movie_names)}: {movie_name}...")
   
    # Search for the movie
    movies = ia.search_movie(movie_name)
    if not movies:
        continue

    # Get the movie ID and fetch the movie details
    movie_id = movies[0].movieID
    movie = ia.get_movie(movie_id)

    # Extract details
    description = movie.get('plot outline', 'N/A')
    synopsis = movie.get('synopsis', 'N/A')
    actors = ', '.join([actor['name'] for actor in movie.get('cast', [])[:10]])  # Take only the first 10 actors
    director = ', '.join([director['name'] for director in movie.get('director', [])])
    duration = movie.get('runtime', ['N/A'])[0]
    release_date = movie.get('original air date', 'N/A')
    genres = ', '.join(movie.get('genres', []))
    rate = movie.get('rating', 'N/A')
    top_250 = movie.get('top 250 rank', 'N/A')
    languages = ', '.join(movie.get('languages', []))
    plot = movie.get('plot', 'N/A')
    producer = ', '.join([producer['name'] for producer in movie.get('producer', [])])
    production_companies = ', '.join([production_company['name'] for production_company in movie.get('production companies', [])])

    # Prepare the content for the text file
    content = (
        f"Title:\n{movie_name}\n\n"
        f"Rating:\n{rate}\n\n"
        f"Top 250 Rank:\n{top_250}\n\n"
        f"Duration:\n{duration}\n\n"
        f"Release Date:\n{release_date}\n\n"
        f"Genres:\n{genres}\n\n"
        f"Director:\n{director}\n\n"
        f"Actors:\n{actors}\n\n"
        f"Languages:\n{languages}\n\n"
        f"Description:\n{description}\n\n"
        f"Synopsis:\n{synopsis}\n\n"
        f"Plot:\n{plot}\n\n"
        f"Producer:\n{producer}\n\n"
        f"Production Companies:\n{production_companies}\n\n"
    )

    # Replace semicolons, colons and question marks in the movie name with underscores
    safe_movie_name = movie_name.replace(':', '_').replace(';', '_').replace('?', '_').replace('/', '_')

    # Write the content to a text file
    with open(os.path.join(output_folder, f"{safe_movie_name}.txt"), 'w', encoding='utf-8') as file:
        file.write(content)

print("Text files created successfully!")
# Out:
# Creating text file for movie 421/204: The Chronicles of Narnia: Prince Caspian...
# Creating text file for movie 422/204: The Guardians...
# Creating text file for movie 423/204: Mafia: Game of Survival...
# Creating text file for movie 424/204: Coma...
# Creating text file for movie 425/204: Cosmoball...
# Creating text file for movie 426/204: Attraction...
# Creating text file for movie 427/204: Invasion...
# Creating text file for movie 428/204: Max Steel...
# Creating text file for movie 429/204: Guardians...
# Creating text file for movie 430/204: Panfilov's 28 Men...
# Creating text file for movie 431/204: Death Race 4: Beyond Anarchy...
# Creating text file for movie 432/204: Gogol. Nachalo...
# Creating text file for movie 433/204: Crimea...
# Creating text file for movie 434/204: Material Girls...
# Creating text file for movie 435/204: The Perfect Man...
# Creating text file for movie 436/204: Raise Your Voice...
# Creating text file for movie 437/204: The Lizzie McGuire Movie...
# Creating text file for movie 438/204: Lizzie McGuire...
# Creating text file for movie 439/204: Cadet Kelly...
# Creating text file for movie 440/204: Get a Clue...
# Creating text file for movie 441/204: New York Minute...
# Creating text file for movie 442/204: Confessions of a Teenage Drama Queen...
# Creating text file for movie 443/204: The Mechanic...
# Creating text file for movie 444/204: Holmes & Watson...
# Creating text file for movie 445/204: Get Hard...
# Creating text file for movie 446/204: The House...
# Creating text file for movie 447/204: The Campaign...
# Creating text file for movie 448/204: Eurovision Song Contest: The Story of Fire Saga...
# Creating text file for movie 449/204: Daddy's Home 2...
# Creating text file for movie 450/204: Anchorman 2: The Legend Continues...
# Creating text file for movie 451/204: Land of the Lost...
# Creating text file for movie 452/204: Talladega Nights: The Ballad of Ricky Bobby...
# Creating text file for movie 453/204: Step Brothers...
# Creating text file for movie 454/204: Casa de mi Padre...
# Creating text file for movie 455/204: Semi-Pro...
# Creating text file for movie 456/204: David...
# Creating text file for movie 457/204: Plan 9 from Outer Space...
# Creating text file for movie 458/204: Bride of the Monster...
# Creating text file for movie 459/204: Glen or Glenda...
# Creating text file for movie 460/204: Night of the Ghouls...
# Creating text file for movie 461/204: Jail Bait...
# Creating text file for movie 462/204: Ed Wood...
# Creating text file for movie 463/204: Plan 9...
# Creating text file for movie 464/204: The Brain That Wouldn't Die...
# Creating text file for movie 465/204: Vampira Returns...
# Creating text file for movie 466/204: The Vampira Show...
# Creating text file for movie 467/204: Plan 9.1 from Outer Space...
# Creating text file for movie 468/204: Frankenstein...
# Creating text file for movie 469/204: The Devil Bat...
# Creating text file for movie 470/204: Beverly Hills Chihuahua 2...
# Creating text file for movie 471/204: Beverly Hills Chihuahua 3: Viva La Fiesta!...
# Creating text file for movie 472/204: Underdog...
# Creating text file for movie 473/204: Treasure Buddies...
# Creating text file for movie 474/204: Santa Buddies...
# Creating text file for movie 475/204: Snow Buddies...
# Creating text file for movie 476/204: Air Buddies...
# Creating text file for movie 477/204: Chihuahua: The Movie...
# Creating text file for movie 478/204: Furry Vengeance...
# Creating text file for movie 479/204: The Fixies...
# Creating text file for movie 480/204: Aliens in the Attic...
# Creating text file for movie 481/204: Son of Bigfoot...
# Creating text file for movie 482/204: Evan Almighty...
# Creating text file for movie 483/204: The Nut Job...
# Creating text file for movie 484/204: The Dudley Do-Right Show...
# Creating text file for movie 485/204: Sinbad: Beyond the Veil of Mists...
# Creating text file for movie 486/204: The Great Muppet Caper...
# Creating text file for movie 487/204: The Flintstones in Viva Rock Vegas...
# Creating text file for movie 488/204: Fat Albert...
# Creating text file for movie 489/204: Shorts...
# Creating text file for movie 490/204: Caddyshack II...
# Creating text file for movie 491/204: Caddyshack...
# Creating text file for movie 492/204: Caddyshack: The 19th Hole...
# Creating text file for movie 493/204: Spies Like Us...
# Creating text file for movie 494/204: National Lampoon's European Vacation...
# Creating text file for movie 495/204: The Great Outdoors...
# Creating text file for movie 496/204: Funny Farm...
# Creating text file for movie 497/204: Revenge of the Nerds II: Nerds in Paradise...
# Creating text file for movie 498/204: Vegas Vacation...
# Creating text file for movie 499/204: Vacation...
# Creating text file for movie 500/204: Revenge of the Nerds...
# Creating text file for movie 501/204: Major League II...
# Creating text file for movie 502/204: Dragnet...
# Creating text file for movie 503/204: Recep Ivedik 4...
# Creating text file for movie 504/204: Recep Ivedik 3...
# Creating text file for movie 505/204: Recep Ivedik 5...
# Creating text file for movie 506/204: Recep Ivedik 2...
# Creating text file for movie 507/204: Recep Ivedik...
# Creating text file for movie 508/204: Recep Ivedik 6...
# Creating text file for movie 509/204: Recep Ivedik 7...
# Creating text file for movie 510/204: Osman Pazarlama...
# Creating text file for movie 511/204: Celal and Ceren...
# Creating text file for movie 512/204: Sacred Demijohn...
# Creating text file for movie 513/204: Sacred Demijohn 2...
# Creating text file for movie 514/204: Çakallarla Dans...
# Creating text file for movie 515/204: Kolpaçino...
# Creating text file for movie 516/204: The NeverEnding Story III...
# Creating text file for movie 517/204: Mac and Me...
# Creating text file for movie 518/204: 3 Ninjas: High Noon at Mega Mountain...
# Creating text file for movie 519/204: Leave It to Beaver...
# Creating text file for movie 520/204: The Master of Disguise...
# Creating text file for movie 521/204: Buddy...
# Creating text file for movie 522/204: Bratz...
# Creating text file for movie 523/204: Treasure Island...
# Creating text file for movie 524/204: Kazaam...
# Creating text file for movie 525/204: The Santa Clause 3: The Escape Clause...
# Creating text file for movie 526/204: Noelle...
# Creating text file for movie 527/204: Home Alone: Deleted Scenes...
# Creating text file for movie 528/204: The Santa Clause 2...
# Creating text file for movie 529/204: The Grinch...
# Creating text file for movie 530/204: The Christmas Chronicles...
# Creating text file for movie 531/204: Swept Away...
# Creating text file for movie 532/204: The Next Best Thing...
# Creating text file for movie 533/204: Shanghai Surprise...
# Creating text file for movie 534/204: Star...
# Creating text file for movie 535/204: Who's That Girl...
# Creating text file for movie 536/204: Evita...
# Creating text file for movie 537/204: Body of Evidence...
# Creating text file for movie 538/204: Revolver...
# Creating text file for movie 539/204: The Hire...
# Creating text file for movie 540/204: Bloodhounds of Broadway...
# Creating text file for movie 541/204: Dick Tracy...
# Creating text file for movie 542/204: Desperately Seeking Susan...
# Creating text file for movie 543/204: S. Darko...
# Creating text file for movie 544/204: Donnie Darko...
# Creating text file for movie 545/204: Sadako...
# Creating text file for movie 546/204: Donnie Darko: Deus Ex Machina - The Philosophy of Donnie Darko...
# Creating text file for movie 547/204: The Donnie Darko Experience...
# Creating text file for movie 548/204: Teaching Mrs. Tingle...
# Creating text file for movie 549/204: The Box...
# Creating text file for movie 550/204: They Made Me Do It Too: The Cult of Donnie Darko...
# Creating text file for movie 551/204: Corpus Christi...
# Creating text file for movie 552/204: Amicus...
# Creating text file for movie 553/204: Southland Tales...
# Creating text file for movie 554/204: Donnie Darko: Easter Edition...
# Creating text file for movie 555/204: 'Donnie Darko': Production Diary...
# Creating text file for movie 556/204: The Titan...
# Creating text file for movie 557/204: Revolt...
# Creating text file for movie 558/204: The Mortal Instruments: City of Bones...
# Creating text file for movie 559/204: Impact...
# Creating text file for movie 560/204: The Space Between Us...
# Creating text file for movie 561/204: Pay the Ghost...
# Creating text file for movie 562/204: Robot Overlords...
# Creating text file for movie 563/204: Pursuit...
# Creating text file for movie 564/204: Stowaway...
# Creating text file for movie 565/204: Day of the Dead: Bloodline...
# Creating text file for movie 566/204: Day of the Dead...
# Creating text file for movie 567/204: Diary of the Dead...
# Creating text file for movie 568/204: Survival of the Dead...
# Creating text file for movie 569/204: Land of the Dead...
# Creating text file for movie 570/204: Cargo...
# Creating text file for movie 571/204: Day of the Dead 2: Contagium...
# Creating text file for movie 572/204: Dead Rising: Endgame...
# Creating text file for movie 573/204: Night of the Animated Dead...
# Creating text file for movie 574/204: Little Monsters...
# Creating text file for movie 575/204: Dead Rising: Watchtower...
# Creating text file for movie 576/204: Santa Claus Conquers the Martians...
# Creating text file for movie 577/204: Foodfight!...
# Creating text file for movie 578/204: The Emoji Movie...
# Creating text file for movie 579/204: The Boss Baby...
# Creating text file for movie 580/204: Home...
# Creating text file for movie 581/204: The Secret Life of Pets...
# Creating text file for movie 582/204: The Autobots...
# Creating text file for movie 583/204: Hotel Transylvania 2...
# Creating text file for movie 584/204: Cloudy with a Chance of Meatballs 2...
# Creating text file for movie 585/204: The Angry Birds Movie 2...
# Creating text file for movie 586/204: Camp Cucamonga...
# Creating text file for movie 587/204: Nukie...
# Creating text file for movie 588/204: Travel Mates...
# Creating text file for movie 589/204: Kayhan...
# Creating text file for movie 590/204: Kolpaçino 3. Devre...
# Creating text file for movie 591/204: The NeverEnding Story II: The Next Chapter...
# Creating text file for movie 592/204: The NeverEnding Story...
# Creating text file for movie 593/204: Grand-Daddy Day Care...
# Creating text file for movie 594/204: Shazam!...
# Creating text file for movie 595/204: First Kid...
# Creating text file for movie 596/204: The Sinbad Show...
# Creating text file for movie 597/204: Bratz: Babyz the Movie...
# Creating text file for movie 598/204: Bratz the Video: Starrin' & Stylin'...
# Creating text file for movie 599/204: 3 Ninjas: Knuckle Up...
# Creating text file for movie 600/204: 3 Ninjas Kick Back...
# Creating text file for movie 601/204: 3 Ninjas...
# Creating text file for movie 602/204: Cats...
# Creating text file for movie 603/204: Kirk Cameron's Saving Christmas...
# Creating text file for movie 604/204: Santa Claus...
# Creating text file for movie 605/204: Baby Geniuses and the Mystery of the Crown Jewels...
# Creating text file for movie 606/204: Baby Geniuses and the Treasures of Egypt...
# Creating text file for movie 607/204: Baby Geniuses and the Space Baby...
# Creating text file for movie 608/204: The Mask...
# Creating text file for movie 609/204: The Oogieloves in the Big Balloon Adventure...
# Creating text file for movie 610/204: My Bedbugs...
# Creating text file for movie 611/204: SpongeBob SquarePants Presents the Tidal Zone...
# Creating text file for movie 612/204: Kamp Koral: SpongeBob's Under Years...
# Creating text file for movie 613/204: The Patrick Star Show...
# Creating text file for movie 614/204: Leo the Lion...
# Creating text file for movie 615/204: The Bad Guys: A Very Bad Holiday...
# Creating text file for movie 616/204: The Bad Guys: Haunted Heist...
# Creating text file for movie 617/204: The Ice Age Adventures of Buck Wild...
# Creating text file for movie 618/204: Saving Bikini Bottom: The Sandy Cheeks Movie...
# Creating text file for movie 619/204: The Little Panda Fighter...
# Creating text file for movie 620/204: Ratatoing...
# Creating text file for movie 621/204: Finding Jesus...
# Creating text file for movie 622/204: What's Up: Balloon to the Rescue!...
# Creating text file for movie 623/204: Little Bee...
# Creating text file for movie 624/204: Mercy Rule...
# Text files created successfully!

# %% [markdown]
# Save the relevant info for a specific movie.

# %%
# Create an instance of the IMDb class
ia = IMDb()

# Specify the movie name for which you want to create the text file
movie_name = "Primal"

# Create a folder to store the text file
output_folder = 'bottom_net_movies_info'
os.makedirs(output_folder, exist_ok=True)

# Search for the movie
movies = ia.search_movie(movie_name)
if not movies:
    print(f"Movie '{movie_name}' not found!")
else:
    # Get the movie ID and fetch the movie details
    movie_id = movies[0].movieID
    movie = ia.get_movie(movie_id)

    # Extract details
    description = movie.get('plot outline', 'N/A')
    synopsis = movie.get('synopsis', 'N/A')
    actors = ', '.join([actor['name'] for actor in movie.get('cast', [])[:10]])  # Take only the first 10 actors
    director = ', '.join([director['name'] for director in movie.get('director', [])])
    duration = movie.get('runtime', ['N/A'])[0]
    release_date = movie.get('original air date', 'N/A')
    genres = ', '.join(movie.get('genres', []))
    rate = movie.get('rating', 'N/A')
    top_250 = movie.get('top 250 rank', 'N/A')
    url = movie.get('full-size cover url', 'N/A')
    languages = ', '.join(movie.get('languages', []))
    plot = movie.get('plot', 'N/A')
    producer = ', '.join([producer['name'] for producer in movie.get('producer', [])])
    production_companies = ', '.join([production_company['name'] for production_company in movie.get('production companies', [])])

    # Prepare the content for the text file
    content = (
        f"Title:\n{movie_name}\n\n"
        f"Rating:\n{rate}\n\n"
        f"Top 250 Rank:\n{top_250}\n\n"
        f"Duration:\n{duration}\n\n"
        f"Release Date:\n{release_date}\n\n"
        f"Genres:\n{genres}\n\n"
        f"Director:\n{director}\n\n"
        f"Actors:\n{actors}\n\n"
        f"Languages:\n{languages}\n\n"
        f"Description:\n{description}\n\n"
        f"Synopsis:\n{synopsis}\n\n"
        f"Plot:\n{plot}\n\n"
        f"Producer:\n{producer}\n\n"
        f"Production Companies:\n{production_companies}\n\n"
    )

    # Replace semicolons, colons and question marks in the movie name with underscores
    safe_movie_name = movie_name.replace(':', '_').replace(';', '_').replace('?', '_').replace('/', '_')

    # Write the content to a text file
    file_path = os.path.join(output_folder, f"{safe_movie_name}.txt")
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(content)

    print(f"Text file for '{movie_name}' created successfully at {file_path}!")
# Out:
# Text file for 'Primal' created successfully at bottom_net_movies_info\Primal.txt!
